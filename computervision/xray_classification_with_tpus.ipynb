# %% [markdown]
# <a href="https://colab.research.google.com/github/NishaMDev/DeepLearning/blob/main/computervision/xray_classification_with_tpus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pneumonia Classification on TPU
#
# **Author:** Amy MiHyun Jang<br>
# **Date created:** 2020/07/28<br>
# **Last modified:** 2020/08/24<br>
# **Description:** Medical image classification on TPU.

# %% [markdown]
# ## Introduction + Set-up
#
# This tutorial will explain how to build an X-ray image classification model
# to predict whether an X-ray scan shows presence of pneumonia.

# %%
import re
import os
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
    print("Device:", tpu.master())
    strategy = tf.distribute.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print("Number of replicas:", strategy.num_replicas_in_sync)
# Out:
# Number of replicas: 1

# %% [markdown]
# We need a Google Cloud link to our data to load the data using a TPU.
# Below, we define key configuration parameters we'll use in this example.
# To run on TPU, this example must be on Colab with the TPU runtime selected.

# %%
AUTOTUNE = tf.data.AUTOTUNE
BATCH_SIZE = 25 * strategy.num_replicas_in_sync
IMAGE_SIZE = [180, 180]
CLASS_NAMES = ["NORMAL", "PNEUMONIA"]

# %% [markdown]
# ## Load the data
#
# The Chest X-ray data we are using from
# [*Cell*](https://www.cell.com/cell/fulltext/S0092-8674(18)30154-5) divides the data into
# training and test files. Let's first load in the training TFRecords.

# %%
train_images = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/train/images.tfrec"
)
train_paths = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/train/paths.tfrec"
)

ds = tf.data.Dataset.zip((train_images, train_paths))

# %% [markdown]
# Let's count how many healthy/normal chest X-rays we have and how many
# pneumonia chest X-rays we have:

# %%
COUNT_NORMAL = len(
    [
        filename
        for filename in train_paths
        if "NORMAL" in filename.numpy().decode("utf-8")
    ]
)
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len(
    [
        filename
        for filename in train_paths
        if "PNEUMONIA" in filename.numpy().decode("utf-8")
    ]
)
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1349
# Pneumonia images count in training set: 3883

# %% [markdown]
# Notice that there are way more images that are classified as pneumonia than normal. This
# shows that we have an imbalance in our data. We will correct for this imbalance later on
# in our notebook.

# %% [markdown]
# We want to map each filename to the corresponding (image, label) pair. The following
# methods will help us do that.
#
# As we only have two labels, we will encode the label so that `1` or `True` indicates
# pneumonia and `0` or `False` indicates normal.

# %%
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, "/")
    # The second to last is the class-directory
    return parts[-2] == "PNEUMONIA"


def decode_img(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_jpeg(img, channels=3)
    # resize the image to the desired size.
    return tf.image.resize(img, IMAGE_SIZE)


def process_path(image, path):
    label = get_label(path)
    # load the raw data from the file as a string
    img = decode_img(image)
    return img, label


ds = ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# Let's split the data into a training and validation datasets.

# %%
ds = ds.shuffle(10000)
train_ds = ds.take(4200)
val_ds = ds.skip(4200)

# %% [markdown]
# Let's visualize the shape of an (image, label) pair.

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  True

# %% [markdown]
# Load and format the test data as well.

# %%
test_images = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/test/images.tfrec"
)
test_paths = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/test/paths.tfrec"
)
test_ds = tf.data.Dataset.zip((test_images, test_paths))

test_ds = test_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

# %% [markdown]
# ## Visualize the dataset
#
# First, let's use buffered prefetching so we can yield data from disk without having I/O
# become blocking.
#
# Please note that large image datasets should not be cached in memory. We do it here
# because the dataset is not very large and we want to train on TPU.

# %%
def prepare_for_training(ds, cache=True):
    # This is a small dataset, only load it once, and keep it in memory.
    # use `.cache(filename)` to cache preprocessing work for datasets that don't
    # fit in memory.
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()

    ds = ds.batch(BATCH_SIZE)

    # `prefetch` lets the dataset fetch batches in the background while the model
    # is training.
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

# %% [markdown]
# Call the next batch iteration of the training data.

# %%
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

image_batch, label_batch = next(iter(train_ds))

# %% [markdown]
# Define the method to show the images in the batch.

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10, 10))
    for n in range(25):
        ax = plt.subplot(5, 5, n + 1)
        plt.imshow(image_batch[n] / 255)
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

# %% [markdown]
# As the method takes in NumPy arrays as its parameters, call the numpy function on the
# batches to return the tensor in NumPy array form.

# %%
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ## Build the CNN
#
# To make our model more modular and easier to understand, let's define some blocks. As
# we're building a convolution neural network, we'll create a convolution block and a dense
# layer block.
#
# The architecture for this CNN has been inspired by this
# [article](https://towardsdatascience.com/deep-learning-for-detecting-pneumonia-from-x-ray-images-fc9a3d9fdba8).

# %%
from tensorflow import keras
from tensorflow.keras import layers


def conv_block(filters, inputs):
    x = layers.SeparableConv2D(filters, 3, activation="relu", padding="same")(inputs)
    x = layers.SeparableConv2D(filters, 3, activation="relu", padding="same")(x)
    x = layers.BatchNormalization()(x)
    outputs = layers.MaxPool2D()(x)

    return outputs


def dense_block(units, dropout_rate, inputs):
    x = layers.Dense(units, activation="relu")(inputs)
    x = layers.BatchNormalization()(x)
    outputs = layers.Dropout(dropout_rate)(x)

    return outputs

# %% [markdown]
# The following method will define the function to build our model for us.
#
# The images originally have values that range from [0, 255]. CNNs work better with smaller
# numbers so we will scale this down for our input.
#
# The Dropout layers are important, as they
# reduce the likelikhood of the model overfitting. We want to end the model with a `Dense`
# layer with one node, as this will be the binary output that determines if an X-ray shows
# presence of pneumonia.

# %%
def build_model():
    inputs = keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
    x = layers.Rescaling(1.0 / 255)(inputs)
    x = layers.Conv2D(16, 3, activation="relu", padding="same")(x)
    x = layers.Conv2D(16, 3, activation="relu", padding="same")(x)
    x = layers.MaxPool2D()(x)

    x = conv_block(32, x)
    x = conv_block(64, x)

    x = conv_block(128, x)
    x = layers.Dropout(0.2)(x)

    x = conv_block(256, x)
    x = layers.Dropout(0.2)(x)

    x = layers.Flatten()(x)
    x = dense_block(512, 0.7, x)
    x = dense_block(128, 0.5, x)
    x = dense_block(64, 0.3, x)

    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# ## Correct for data imbalance
#
# We saw earlier in this example that the data was imbalanced, with more images classified
# as pneumonia than normal. We will correct for that by using class weighting:

# %%
initial_bias = np.log([COUNT_PNEUMONIA / COUNT_NORMAL])
print("Initial bias: {:.5f}".format(initial_bias[0]))

TRAIN_IMG_COUNT = COUNT_NORMAL + COUNT_PNEUMONIA
weight_for_0 = (1 / COUNT_NORMAL) * (TRAIN_IMG_COUNT) / 2.0
weight_for_1 = (1 / COUNT_PNEUMONIA) * (TRAIN_IMG_COUNT) / 2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print("Weight for class 0: {:.2f}".format(weight_for_0))
print("Weight for class 1: {:.2f}".format(weight_for_1))
# Out:
# Initial bias: 1.05724
# Weight for class 0: 1.94
# Weight for class 1: 0.67

# %% [markdown]
# The weight for class `0` (Normal) is a lot higher than the weight for class `1`
# (Pneumonia). Because there are less normal images, each normal image will be weighted
# more to balance the data as the CNN works best when the training data is balanced.

# %% [markdown]
# ## Train the model

# %% [markdown]
# ### Defining callbacks
#
# The checkpoint callback saves the best weights of the model, so next time we want to use
# the model, we do not have to spend time training it. The early stopping callback stops
# the training process when the model starts becoming stagnant, or even worse, when the
# model starts overfitting.

# %%
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("xray_model.h5", save_best_only=True)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(
    patience=10, restore_best_weights=True
)

# %% [markdown]
# We also want to tune our learning rate. Too high of a learning rate will cause the model
# to diverge. Too small of a learning rate will cause the model to be too slow. We
# implement the exponential learning rate scheduling method below.

# %%
initial_learning_rate = 0.015
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)

# %% [markdown]
# ### Fit the model
#
# For our metrics, we want to include precision and recall as they will provide use with a
# more informed picture of how good our model is. Accuracy tells us what fraction of the
# labels is correct. Since our data is not balanced, accuracy might give a skewed sense of
# a good model (i.e. a model that always predicts PNEUMONIA will be 74% accurate but is not
# a good model).
#
# Precision is the number of true positives (TP) over the sum of TP and false positives
# (FP). It shows what fraction of labeled positives are actually correct.
#
# Recall is the number of TP over the sum of TP and false negatves (FN). It shows what
# fraction of actual positives are correct.
#
# Since there are only two possible labels for the image, we will be using the
# binary crossentropy loss. When we fit the model, remember to specify the class weights,
# which we defined earlier. Because we are using a TPU, training will be quick - less than
# 2 minutes.

# %%
with strategy.scope():
    model = build_model()

    METRICS = [
        tf.keras.metrics.BinaryAccuracy(),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall"),
    ]
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
        loss="binary_crossentropy",
        metrics=METRICS,
    )

history = model.fit(
    train_ds,
    epochs=100,
    validation_data=val_ds,
    class_weight=class_weight,
    callbacks=[checkpoint_cb, early_stopping_cb],
)
# Out:
# Epoch 1/100
# 168/168 [==============================] - 88s 265ms/step - loss: 0.4851 - binary_accuracy: 0.7805 - precision: 0.9175 - recall: 0.7738 - val_loss: 17.5243 - val_binary_accuracy: 0.2636 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 168/168 [==============================] - 14s 85ms/step - loss: 0.3566 - binary_accuracy: 0.8424 - precision: 0.9411 - recall: 0.8402 - val_loss: 0.2376 - val_binary_accuracy: 0.9196 - val_precision: 0.9669 - val_recall: 0.9224
# Epoch 3/100
# 168/168 [==============================] - 14s 85ms/step - loss: 0.2788 - binary_accuracy: 0.8893 - precision: 0.9598 - recall: 0.8880 - val_loss: 0.3921 - val_binary_accuracy: 0.8634 - val_precision: 0.9813 - val_recall: 0.8303
# Epoch 4/100
# 168/168 [==============================] - 14s 85ms/step - loss: 0.2440 - binary_accuracy: 0.9005 - precision: 0.9668 - recall: 0.8967 - val_loss: 0.3059 - val_binary_accuracy: 0.8953 - val_precision: 0.9910 - val_recall: 0.8658
# Epoch 5/100
# 168/168 [==============================] - 14s 85ms/step - loss: 0.2141 - binary_accuracy: 0.9169 - precision: 0.9727 - recall: 0.9137 - val_loss: 1.5514 - val_binary_accuracy: 0.5785 - val_precision: 1.0000 - val_recall: 0.4276
# Epoch 6/100
# 168/168 [==============================] - 14s 85ms/step - loss: 0.2090 - binary_accuracy: 0.9262 - precision: 0.9762 - recall: 0.9230 - val_loss: 0.5590 - val_binary_accuracy: 0.7616 - val_precision: 0.7555 - val_recall: 1.0000
# Epoch 7/100
# 168/168 [==============================] - 14s 85ms/step - loss: 0.1827 - binary_accuracy: 0.9348 - precision: 0.9791 - recall: 0.9320 - val_loss: 1.0780 - val_binary_accuracy: 0.6996 - val_precision: 1.0000 - val_recall: 0.5921
# Epoch 8/100
# 168/168 [==============================] - 14s 85ms/step - loss: 0.1815 - binary_accuracy: 0.9288 - precision: 0.9783 - recall: 0.9246 - val_loss: 0.4295 - val_binary_accuracy: 0.8711 - val_precision: 0.9953 - val_recall: 0.8289
# Epoch 9/100
# 168/168 [==============================] - 15s 86ms/step - loss: 0.1646 - binary_accuracy: 0.9345 - precision: 0.9791 - recall: 0.9317 - val_loss: 0.1252 - val_binary_accuracy: 0.9583 - val_precision: 0.9786 - val_recall: 0.9645
# Epoch 10/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.1628 - binary_accuracy: 0.9381 - precision: 0.9815 - recall: 0.9342 - val_loss: 2.2454 - val_binary_accuracy: 0.7364 - val_precision: 0.7364 - val_recall: 1.0000
# Epoch 11/100
# 168/168 [==============================] - 14s 85ms/step - loss: 0.1628 - binary_accuracy: 0.9417 - precision: 0.9825 - recall: 0.9381 - val_loss: 0.2069 - val_binary_accuracy: 0.9118 - val_precision: 0.9970 - val_recall: 0.8829
# Epoch 12/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.1460 - binary_accuracy: 0.9452 - precision: 0.9829 - recall: 0.9426 - val_loss: 0.1821 - val_binary_accuracy: 0.9448 - val_precision: 0.9889 - val_recall: 0.9355
# Epoch 13/100
# 168/168 [==============================] - 14s 85ms/step - loss: 0.1479 - binary_accuracy: 0.9436 - precision: 0.9839 - recall: 0.9394 - val_loss: 0.2770 - val_binary_accuracy: 0.8876 - val_precision: 0.9777 - val_recall: 0.8671
# Epoch 14/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.1505 - binary_accuracy: 0.9390 - precision: 0.9831 - recall: 0.9339 - val_loss: 0.3673 - val_binary_accuracy: 0.8682 - val_precision: 0.9561 - val_recall: 0.8605
# Epoch 15/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.1633 - binary_accuracy: 0.9419 - precision: 0.9816 - recall: 0.9394 - val_loss: 0.7641 - val_binary_accuracy: 0.8140 - val_precision: 1.0000 - val_recall: 0.7474
# Epoch 16/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.1938 - binary_accuracy: 0.9283 - precision: 0.9799 - recall: 0.9224 - val_loss: 13.0668 - val_binary_accuracy: 0.7374 - val_precision: 0.7376 - val_recall: 0.9987
# Epoch 17/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.1969 - binary_accuracy: 0.9283 - precision: 0.9773 - recall: 0.9249 - val_loss: 0.1433 - val_binary_accuracy: 0.9428 - val_precision: 0.9888 - val_recall: 0.9329
# Epoch 18/100
# 168/168 [==============================] - 14s 86ms/step - loss: 0.1363 - binary_accuracy: 0.9486 - precision: 0.9869 - recall: 0.9432 - val_loss: 0.0977 - val_binary_accuracy: 0.9583 - val_precision: 0.9638 - val_recall: 0.9803
# Epoch 19/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.1261 - binary_accuracy: 0.9519 - precision: 0.9847 - recall: 0.9500 - val_loss: 0.1588 - val_binary_accuracy: 0.9331 - val_precision: 0.9971 - val_recall: 0.9118
# Epoch 20/100
# 168/168 [==============================] - 14s 85ms/step - loss: 0.1572 - binary_accuracy: 0.9407 - precision: 0.9835 - recall: 0.9358 - val_loss: 0.2602 - val_binary_accuracy: 0.9419 - val_precision: 0.9605 - val_recall: 0.9605
# Epoch 21/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.1541 - binary_accuracy: 0.9481 - precision: 0.9837 - recall: 0.9458 - val_loss: 0.1034 - val_binary_accuracy: 0.9622 - val_precision: 0.9891 - val_recall: 0.9592
# Epoch 22/100
# 168/168 [==============================] - 14s 85ms/step - loss: 0.1281 - binary_accuracy: 0.9519 - precision: 0.9860 - recall: 0.9487 - val_loss: 0.1267 - val_binary_accuracy: 0.9428 - val_precision: 0.9902 - val_recall: 0.9316
# Epoch 23/100
# 168/168 [==============================] - 14s 85ms/step - loss: 0.1235 - binary_accuracy: 0.9519 - precision: 0.9876 - recall: 0.9471 - val_loss: 0.1121 - val_binary_accuracy: 0.9564 - val_precision: 0.9945 - val_recall: 0.9461
# Epoch 24/100
# 168/168 [==============================] - 14s 85ms/step - loss: 0.1606 - binary_accuracy: 0.9398 - precision: 0.9818 - recall: 0.9362 - val_loss: 0.1873 - val_binary_accuracy: 0.9322 - val_precision: 0.9957 - val_recall: 0.9118
# Epoch 25/100
# 168/168 [==============================] - 14s 85ms/step - loss: 0.1260 - binary_accuracy: 0.9507 - precision: 0.9847 - recall: 0.9483 - val_loss: 0.2429 - val_binary_accuracy: 0.9021 - val_precision: 1.0000 - val_recall: 0.8671
# Epoch 26/100
# 168/168 [==============================] - 15s 87ms/step - loss: 0.1125 - binary_accuracy: 0.9600 - precision: 0.9894 - recall: 0.9564 - val_loss: 0.0969 - val_binary_accuracy: 0.9593 - val_precision: 0.9959 - val_recall: 0.9487
# Epoch 27/100
# 168/168 [==============================] - 14s 85ms/step - loss: 0.1028 - binary_accuracy: 0.9638 - precision: 0.9888 - recall: 0.9621 - val_loss: 0.0999 - val_binary_accuracy: 0.9603 - val_precision: 1.0000 - val_recall: 0.9461
# Epoch 28/100
# 168/168 [==============================] - 14s 85ms/step - loss: 0.1531 - binary_accuracy: 0.9436 - precision: 0.9829 - recall: 0.9403 - val_loss: 0.1449 - val_binary_accuracy: 0.9360 - val_precision: 0.9943 - val_recall: 0.9184
# Epoch 29/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.1434 - binary_accuracy: 0.9479 - precision: 0.9840 - recall: 0.9451 - val_loss: 0.4182 - val_binary_accuracy: 0.8469 - val_precision: 1.0000 - val_recall: 0.7921
# Epoch 30/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.1088 - binary_accuracy: 0.9581 - precision: 0.9884 - recall: 0.9548 - val_loss: 0.3456 - val_binary_accuracy: 0.8605 - val_precision: 1.0000 - val_recall: 0.8105
# Epoch 31/100
# 168/168 [==============================] - 14s 83ms/step - loss: 0.0984 - binary_accuracy: 0.9602 - precision: 0.9900 - recall: 0.9560 - val_loss: 0.1505 - val_binary_accuracy: 0.9360 - val_precision: 0.9986 - val_recall: 0.9145
# Epoch 32/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.0933 - binary_accuracy: 0.9657 - precision: 0.9895 - recall: 0.9641 - val_loss: 0.1173 - val_binary_accuracy: 0.9496 - val_precision: 0.9972 - val_recall: 0.9342
# Epoch 33/100
# 168/168 [==============================] - 14s 86ms/step - loss: 0.1014 - binary_accuracy: 0.9638 - precision: 0.9901 - recall: 0.9609 - val_loss: 0.0678 - val_binary_accuracy: 0.9729 - val_precision: 0.9946 - val_recall: 0.9684
# Epoch 34/100
# 168/168 [==============================] - 14s 83ms/step - loss: 0.0852 - binary_accuracy: 0.9679 - precision: 0.9911 - recall: 0.9654 - val_loss: 0.2111 - val_binary_accuracy: 0.9176 - val_precision: 1.0000 - val_recall: 0.8882
# Epoch 35/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.0787 - binary_accuracy: 0.9712 - precision: 0.9928 - recall: 0.9682 - val_loss: 0.1686 - val_binary_accuracy: 0.9283 - val_precision: 0.9928 - val_recall: 0.9092
# Epoch 36/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.0877 - binary_accuracy: 0.9676 - precision: 0.9892 - recall: 0.9670 - val_loss: 0.1704 - val_binary_accuracy: 0.9293 - val_precision: 1.0000 - val_recall: 0.9039
# Epoch 37/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.0765 - binary_accuracy: 0.9738 - precision: 0.9931 - recall: 0.9714 - val_loss: 0.2504 - val_binary_accuracy: 0.9021 - val_precision: 0.9985 - val_recall: 0.8684
# Epoch 38/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.0946 - binary_accuracy: 0.9645 - precision: 0.9911 - recall: 0.9609 - val_loss: 0.1542 - val_binary_accuracy: 0.9331 - val_precision: 0.9986 - val_recall: 0.9105
# Epoch 39/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.1063 - binary_accuracy: 0.9586 - precision: 0.9858 - recall: 0.9580 - val_loss: 1.5873 - val_binary_accuracy: 0.8285 - val_precision: 0.9866 - val_recall: 0.7776
# Epoch 40/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.1313 - binary_accuracy: 0.9548 - precision: 0.9861 - recall: 0.9525 - val_loss: 0.2425 - val_binary_accuracy: 0.9138 - val_precision: 0.9985 - val_recall: 0.8842
# Epoch 41/100
# 168/168 [==============================] - 14s 86ms/step - loss: 0.1028 - binary_accuracy: 0.9586 - precision: 0.9887 - recall: 0.9551 - val_loss: 0.0525 - val_binary_accuracy: 0.9806 - val_precision: 0.9947 - val_recall: 0.9789
# Epoch 42/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.0772 - binary_accuracy: 0.9736 - precision: 0.9944 - recall: 0.9698 - val_loss: 0.0631 - val_binary_accuracy: 0.9729 - val_precision: 0.9973 - val_recall: 0.9658
# Epoch 43/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.1086 - binary_accuracy: 0.9598 - precision: 0.9881 - recall: 0.9573 - val_loss: 0.2064 - val_binary_accuracy: 0.9186 - val_precision: 0.9985 - val_recall: 0.8908
# Epoch 44/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.0762 - binary_accuracy: 0.9721 - precision: 0.9937 - recall: 0.9686 - val_loss: 0.1629 - val_binary_accuracy: 0.9399 - val_precision: 0.9972 - val_recall: 0.9211
# Epoch 45/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.1131 - binary_accuracy: 0.9552 - precision: 0.9864 - recall: 0.9528 - val_loss: 0.1037 - val_binary_accuracy: 0.9661 - val_precision: 0.9945 - val_recall: 0.9592
# Epoch 46/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.0888 - binary_accuracy: 0.9643 - precision: 0.9885 - recall: 0.9631 - val_loss: 0.1237 - val_binary_accuracy: 0.9535 - val_precision: 1.0000 - val_recall: 0.9368
# Epoch 47/100
# 168/168 [==============================] - 14s 86ms/step - loss: 0.0714 - binary_accuracy: 0.9726 - precision: 0.9951 - recall: 0.9679 - val_loss: 0.0427 - val_binary_accuracy: 0.9826 - val_precision: 0.9973 - val_recall: 0.9789
# Epoch 48/100
# 168/168 [==============================] - 14s 83ms/step - loss: 0.0641 - binary_accuracy: 0.9774 - precision: 0.9935 - recall: 0.9759 - val_loss: 0.0438 - val_binary_accuracy: 0.9884 - val_precision: 0.9921 - val_recall: 0.9921
# Epoch 49/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.1095 - binary_accuracy: 0.9595 - precision: 0.9881 - recall: 0.9570 - val_loss: 0.2326 - val_binary_accuracy: 0.9099 - val_precision: 1.0000 - val_recall: 0.8776
# Epoch 50/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.0847 - binary_accuracy: 0.9643 - precision: 0.9911 - recall: 0.9605 - val_loss: 0.0686 - val_binary_accuracy: 0.9709 - val_precision: 0.9973 - val_recall: 0.9632
# Epoch 51/100
# 168/168 [==============================] - 14s 85ms/step - loss: 0.0672 - binary_accuracy: 0.9755 - precision: 0.9931 - recall: 0.9737 - val_loss: 0.1526 - val_binary_accuracy: 0.9457 - val_precision: 1.0000 - val_recall: 0.9263
# Epoch 52/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.1071 - binary_accuracy: 0.9605 - precision: 0.9894 - recall: 0.9570 - val_loss: 0.1542 - val_binary_accuracy: 0.9370 - val_precision: 0.9986 - val_recall: 0.9158
# Epoch 53/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.0732 - binary_accuracy: 0.9719 - precision: 0.9931 - recall: 0.9689 - val_loss: 0.0520 - val_binary_accuracy: 0.9748 - val_precision: 0.9959 - val_recall: 0.9697
# Epoch 54/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.0580 - binary_accuracy: 0.9810 - precision: 0.9951 - recall: 0.9791 - val_loss: 0.0690 - val_binary_accuracy: 0.9729 - val_precision: 0.9973 - val_recall: 0.9658
# Epoch 55/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.0822 - binary_accuracy: 0.9705 - precision: 0.9921 - recall: 0.9679 - val_loss: 0.3531 - val_binary_accuracy: 0.8915 - val_precision: 0.9954 - val_recall: 0.8566
# Epoch 56/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.1454 - binary_accuracy: 0.9445 - precision: 0.9832 - recall: 0.9413 - val_loss: 0.3893 - val_binary_accuracy: 0.8537 - val_precision: 1.0000 - val_recall: 0.8013
# Epoch 57/100
# 168/168 [==============================] - 14s 84ms/step - loss: 0.0943 - binary_accuracy: 0.9681 - precision: 0.9918 - recall: 0.9650 - val_loss: 0.3768 - val_binary_accuracy: 0.8643 - val_precision: 1.0000 - val_recall: 0.8158

# %% [markdown]
# ## Visualizing model performance
#
# Let's plot the model accuracy and loss for the training and the validating set. Note that
# no random seed is specified for this notebook. For your notebook, there might be slight
# variance.

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(["precision", "recall", "binary_accuracy", "loss"]):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history["val_" + met])
    ax[i].set_title("Model {}".format(met))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(met)
    ax[i].legend(["train", "val"])

# %% [markdown]
# We see that the accuracy for our model is around 95%.

# %% [markdown]
# ## Predict and evaluate results
#
# Let's evaluate the model on our test data!

# %%
model.evaluate(test_ds, return_dict=True)
# Out:
# 25/25 [==============================] - 4s 133ms/step - loss: 1.2262 - binary_accuracy: 0.7724 - precision: 0.7366 - recall: 0.9897
# {'binary_accuracy': 0.7724359035491943,
#  'loss': 1.2261834144592285,
#  'precision': 0.7366412281990051,
#  'recall': 0.9897435903549194}

# %% [markdown]
# We see that our accuracy on our test data is lower than the accuracy for our validating
# set. This may indicate overfitting.
#
# Our recall is greater than our precision, indicating that almost all pneumonia images are
# correctly identified but some normal images are falsely identified. We should aim to
# increase our precision.

# %%
for image, label in test_ds.take(1):
    plt.imshow(image[0] / 255.0)
    plt.title(CLASS_NAMES[label[0].numpy()])

prediction = model.predict(test_ds.take(1))[0]
scores = [1 - prediction, prediction]

for score, name in zip(scores, CLASS_NAMES):
    print("This image is %.2f percent %s" % ((100 * score), name))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   This is separate from the ipykernel package so we can avoid doing imports until
# This image is 25.66 percent NORMAL
# This image is 74.34 percent PNEUMONIA
